# %%
# !pip install numpy

# %%
from transformers import pipeline
sentiment_pipeline = pipeline("text-classification")
sentiment_pipeline(input())
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# movie is bad
# [{'label': 'NEGATIVE', 'score': 0.9998016953468323}]

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import pipeline

model_name = "distilbert-base-uncased-finetuned-sst-2-english"
sentiment_pipeline = pipeline("sentiment-analysis", model=model_name)


texts = [
    "I absolutely love this product!",
    "This was a terrible experience.",
    "I'm not sure how I feel about this.",
]


results = sentiment_pipeline(texts)
for text, result in zip(texts, results):
    print(f"Text: {text} | Sentiment: {result['label']} | Score: {result['score']}")
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Text: I absolutely love this product! | Sentiment: POSITIVE | Score: 0.9998854398727417
# Text: This was a terrible experience. | Sentiment: NEGATIVE | Score: 0.9989833235740662
# Text: I'm not sure how I feel about this. | Sentiment: NEGATIVE | Score: 0.9992402791976929

# %%
# !pip install faiss-gpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 10.2 MB/s eta 0:00:00
# ...

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer
from sentence_transformers import SentenceTransformer, util
import torch

# Load the generator and retriever
retriever = SentenceTransformer('multi-qa-mpnet-base-dot-v1')  # Dense retriever
generator = T5ForConditionalGeneration.from_pretrained('t5-small')
tokenizer = T5Tokenizer.from_pretrained('t5-small')

# Create the knowledge base
documents = [
    "Retrieval-Augmented Generation (RAG) combines retrieval and generation for improved AI responses.",
    "RAG is used to retrieve context from external databases to inform generative models.",
    "The retrieval component in RAG fetches relevant documents or snippets based on the input query.",
    "RAG models like T5 and GPT can generate more accurate responses by using retrieved knowledge.",
    "RAG systems are highly effective in domains like customer support, document summarization, and knowledge-based question answering.",
    "RAG uses a retriever to identify relevant information from a large knowledge base.",
    "The generator in RAG produces coherent and contextually relevant responses using retrieved information.",
    "RAG leverages the strengths of both information retrieval and generative language models.",
    "RAG improves the performance of chatbots by providing them access to external knowledge.",
    "In RAG, the retrieval model can use techniques like BM25 or Dense Passage Retrieval (DPR).",
    "RAG can be implemented with various retrieval models, including vector search and traditional keyword-based methods.",
    "The retrieval process in RAG is crucial to fetch the most relevant documents or data for the query.",
    "A generative model in RAG typically employs architectures like T5 or GPT.",
    "RAG allows chatbots to access real-time information for more up-to-date answers.",
    "Dense retrieval in RAG uses embeddings and vector search for better accuracy compared to traditional methods.",
    "The integration of retrieval with generation allows RAG to handle complex queries more effectively.",
    "RAG improves the scalability of AI systems by allowing them to handle large knowledge bases.",
    "One of the primary benefits of RAG is its ability to generate answers based on external sources, reducing reliance on model memorization.",
    "RAG systems are often used in search engines to provide context-aware, detailed responses.",
    "The retriever in RAG fetches relevant documents from sources such as databases, websites, or indexed content.",
    "Retrieval-Augmented Generation is particularly useful in handling long-tail queries that require specific knowledge.",
    "RAG systems can integrate with existing document management systems to enhance their response generation capabilities.",
    "The quality of the response in RAG heavily depends on the quality of the retrieved information.",
    "The generator in RAG synthesizes information from the retrieved documents to create a fluent response.",
    "A major challenge in RAG is balancing retrieval speed and the quality of the generated answer.",
    "RAG helps reduce the need for training large generative models by supplementing them with external knowledge.",
    "RAG-based systems can be trained on domain-specific data to improve the accuracy of responses in specialized fields.",
    "The retriever in RAG can be tuned to focus on specific types of documents or content.",
    "RAG is a key component in building more intelligent AI systems that require up-to-date and context-aware responses.",
    "The retrieval model in RAG can use both dense and sparse representations for document retrieval.",
    "A critical feature of RAG is the ability to retrieve context from large, unstructured datasets.",
    "RAG models improve upon traditional generative models by incorporating real-world, up-to-date data into the response.",
    "The integration of retrieval and generation in RAG can help reduce hallucinations in generative models.",
    "By incorporating external knowledge, RAG systems can provide more accurate answers without requiring excessive retraining.",
    "RAG systems can be used for real-time document summarization in news or legal fields.",
    "In customer support, RAG systems can provide detailed answers by retrieving product manuals or FAQs.",
    "RAG models excel at answering questions that involve specific facts or knowledge, such as historical dates or scientific data.",
    "The retriever in RAG models can be based on either dense or sparse vector representations, depending on the retrieval strategy.",
    "RAG is a hybrid approach, combining the best of both information retrieval and generative techniques.",
    "The generation part of RAG ensures that the retrieved content is formatted and presented in a natural language.",
    "With RAG, models can generate responses based on external sources, allowing for accurate and comprehensive answers.",
    "RAG can be used to provide answers to queries that require reasoning over multiple documents.",
    "The retriever in RAG narrows down the search space, making it more efficient than traditional search systems.",
    "RAG-based models are capable of providing more specific and domain-relevant responses compared to general generative models.",
    "RAG helps bridge the gap between unsupervised language models and real-world knowledge.",
    "RAG models are increasingly being used in healthcare applications to retrieve and generate medical information.",
    "RAG systems can be used for legal document analysis, providing summarized answers based on retrieved case law.",
    "RAG can help improve AI systems for interactive applications, such as intelligent personal assistants.",
    "By using RAG, models can handle ambiguous or complex queries by relying on external knowledge.",
    "RAG enhances the ability of AI systems to handle domain-specific questions that require high precision.",
    "RAG systems are designed to work efficiently with large-scale, unstructured data sources like the web or company databases.",
    "The retriever in RAG ensures that relevant and authoritative information is retrieved to enhance the response quality.",
    "RAG-based models are valuable for applications that require timely and accurate information, such as finance or stock market analysis.",
    "RAG helps generative models stay relevant in ever-changing domains by using external knowledge for real-time updates.",
    "By combining retrieval and generation, RAG reduces the dependency on large datasets for training generative models.",
    "RAG models can be tailored to specific industries, enhancing their performance in specialized domains like law, medicine, or finance.",
    "The retrieval process in RAG is optimized to find context that is not only relevant but also sufficiently informative for answering queries.",
    "RAG provides a way to integrate information from both structured and unstructured data sources.",
    "RAG can significantly improve the performance of existing conversational AI systems by enhancing their factual knowledge base.",
    "RAG systems can retrieve and generate information in real-time, improving the interactivity and usefulness of chatbots.",
    "In RAG, the retrieval model is typically trained on large, external datasets, while the generative model focuses on language fluency and coherence.",
    "RAG systems can use multiple retrieval techniques to ensure that they fetch the most relevant content for generating responses.",
    "RAG allows for more precise and contextually aware answers compared to models that generate responses from a fixed set of knowledge.",
    "RAG enables AI systems to incorporate knowledge from diverse sources, making them more adaptable to various domains.",
    "RAG has the potential to revolutionize the way AI interacts with users, providing them with information that is both accurate and context-specific.",
    "By integrating retrieval into the generation process, RAG makes it possible to create more intelligent and knowledgeable AI assistants.",
    "RAG helps overcome the limitation of generative models that may lack domain-specific knowledge or rely on outdated training data.",
    "The retriever in RAG ensures that the generated answers are not based on hallucinations but are grounded in real data.",
    "RAG is a promising approach for building AI systems that need to provide detailed, accurate answers in real-time.",
    "In RAG, the retriever and generator work together to create an end-to-end system for answering complex questions.",
    "The use of retrieval models in RAG allows for the rapid fetching of relevant data without the need to re-train generative models.",
    "RAG improves the robustness of AI systems by allowing them to fetch data from trusted, verified sources.",
    "RAG helps mitigate biases that might be present in generative models by grounding responses in actual data.",
    "The performance of a RAG system depends on the quality and relevance of the retrieved documents or data.",
    "By combining generative capabilities with information retrieval, RAG enables AI systems to generate high-quality, informed responses.",
    "RAG helps reduce the carbon footprint of training large-scale models by incorporating external knowledge without requiring retraining of generative models.",
    "RAG systems can be used to answer domain-specific questions, such as scientific queries, without having to pre-program responses.",
    "In industries like e-commerce, RAG can help generate product recommendations based on customer queries and available product data.",
    "RAG systems are designed to work with various types of data, including structured data from databases and unstructured data from documents or websites.",
    "RAG can improve the accuracy of knowledge-based question answering by combining generative models with a retrieval step.",
    "By using RAG, AI systems can focus on both language fluency and the accuracy of the factual content they generate.",
    "RAG can help AI systems become more self-sufficient by retrieving knowledge from external sources rather than relying solely on pre-trained models.",
    "In applications like search engines, RAG enables the retrieval of contextually relevant documents, followed by a generative model creating summaries or answers.",
    "RAG allows for efficient question answering by narrowing down the pool of potential answers through document retrieval and synthesis.",
    "RAG-based systems can be fine-tuned for specific tasks, such as product searches or answering technical questions, improving their relevance and accuracy.",
    "RAG represents a significant step forward in AI's ability to interact with humans in a more intelligent and context-aware manner.",
    "By leveraging external knowledge sources, RAG can improve the diversity and quality of responses generated by AI systems.",
    "RAG enables AI systems to integrate new data sources without needing to retrain the entire model, making them more scalable and adaptable.",
    "RAG-based systems can retrieve information from structured datasets like knowledge graphs, as well as unstructured text sources like articles"]
doc_embeddings = retriever.encode(documents, convert_to_tensor=True)

# User query
query = "What is RAG?"
query_embedding = retriever.encode(query, convert_to_tensor=True)

# Generate response
input_text = f"question: {query} context: {retrieved_text}"
input_ids = tokenizer.encode(input_text, return_tensors="pt")
outputs = generator.generate(input_ids, max_length=50)
response = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("Response:", response)
# Out:
# Response: hybrid approach

# %%
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 97.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
# ...

# %%
from langchain.chains import LLMChain
from langchain.llms import HuggingFacePipeline
from transformers import pipeline, GPT2Tokenizer, GPT2LMHeadModel

# %%
from langchain.chains import LLMChain
from langchain.llms import HuggingFacePipeline
from langchain.prompts import PromptTemplate
from transformers import pipeline, GPT2Tokenizer, GPT2LMHeadModel

# Load GPT-2 model and tokenizer from Hugging Face
model_name = "gpt2"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Define a HuggingFace pipeline for text generation
generator = pipeline("text-generation", model=model, tokenizer=tokenizer,max_length=50)

# Create the HuggingFace pipeline wrapper for Langchain
hf_pipeline = HuggingFacePipeline(pipeline=generator)

# Define a simple prompt template
template = "Tell me more about {topic}."
prompt = PromptTemplate(input_variables=["topic"], template=template)

# Define the LLMChain with the pipeline and prompt
llm_chain = LLMChain(llm=hf_pipeline, prompt=prompt)

# Run the chain with a topic input
topic_input = "WHat does it mean by RAG"
result = llm_chain({"topic": topic_input})

# Print the result
print(result)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# {'topic': 'WHat does it mean by RAG', 'text': 'Tell me more about WHat does it mean by RAG. I bet a lot of you thought just that!\n\nWe should all be aware of what this means when it comes to getting up early. All we need is a good amount of'}
